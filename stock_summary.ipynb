# %% [markdown]
# # Stock Tracking Jupyter

# %%
from chatgpt import chat_with_gpt
from stock_ticker import make_charts

stock_list = ["AAPL", "AMZN", "GOOG", "META", "MSFT", "NVDA", "TSLA"]

prompt = "Please give me a summary of how these stocks performed and percentage change daily and in the last 5 days with this data:"
chat_with_gpt(prompt, stock_list)
make_charts()
# Out:
# Here's a summary of how the given stocks performed and their percentage changes on the last trading day (November 6, 2024) as well as over the last three trading days (as only three days of data are provided):
#
# ### AAPL (Apple Inc.)
# - **November 6, 2024:**
#   - **Open:** 222.61
#   - **Close:** 222.72
#   - **Percentage Change (Daily):** \((222.72 - 222.61) / 222.61 \times 100 \approx 0.05\%\)
#
# - **Over the Last 3 Days:**
#   - **November 4, 2024 Open:** 220.99
#   - **November 6, 2024 Close:** 222.72
#   - **Percentage Change (3 Days):** \((222.72 - 220.99) / 220.99 \times 100 \approx 0.78\%\)
#
# ### AMZN (Amazon.com Inc.)
# - **November 6, 2024:**
#   - **Open:** 200.01
#   - **Close:** 207.09
#   - **Percentage Change (Daily):** \((207.09 - 200.01) / 200.01 \times 100 \approx 3.54\%\)
#
# - **Over the Last 3 Days:**
#   - **November 4, 2024 Open:** 196.45
#   - **November 6, 2024 Close:** 207.09
# ...
