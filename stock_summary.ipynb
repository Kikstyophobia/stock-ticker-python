# %% [markdown]
# # Stock Tracking Jupyter

# %%
from chatgpt import chat_with_gpt
from stock_ticker import get_stock_data, make_charts

stock_list = ["AAPL", "AMZN", "GOOG", "META", "MSFT", "NVDA", "TSLA"]
prompt = "Please give me a summary of how these stocks performed and percentage change daily and in the last 5 days with this data:"

data = get_stock_data(stock_list)
chat_with_gpt(prompt, data)
make_charts(data)
# Out:
# To summarize the stock performance and calculate the daily and 5-day percentage changes for each stock provided, let's break down the information by stock symbol.
#
# ### AAPL (Apple Inc.)
# - **November 7, 2024:**
#   - Open: 224.62500, Close: 227.69000
#   - **Daily Change:** \(((227.69000 - 224.62500) / 224.62500) \times 100 \approx 1.36\%\)
# - **5-day Start:** No information is given for 5 days fully, so using the latest available:
#   - November 4 to November 7
#   - November 4 Close: 222.00999
#   - November 7 Close: 227.69000
#   - **5-day Change:** \(((227.69000 - 222.00999) / 222.00999) \times 100 \approx 2.55\%\)
#
# ### AMZN (Amazon.com, Inc.)
# - **November 7, 2024:**
#   - Open: 207.41499, Close: 210.22000
#   - **Daily Change:** \(((210.22000 - 207.41499) / 207.41499) \times 100 \approx 1.35\%\)
# - **5-day Start:** (Using available data from November 4)
#   - November 4 Close: 195.78000
#   - November 7 Close: 210.22000
#   - **5-day Change:** \(((210.22000 - 195.78000) / 195.78000) \times 100 \approx 7.38\%\)
#
# ### GOOG (Alphabet Inc.)
# - **November 7, 2024:**
#   - Open: 179.18500, Close: 182.28999
#   - **Daily Change:** \(((182.28999 - 179.18500) / 179.18500) \times 100 \approx 1.73\%\)
# - **5-day Start:** (From November 4)
#   - November 4 Close: 170.67999
#   - November 7 Close: 182.28999
#   - **5-day Change:** \(((182.28999 - 170.67999) / 170.67999) \times 100 \approx 6.82\%\)
#
# ### META (Meta Platforms, Inc.)
# - **November 7, 2024:**
#   - Open: 576.40002, Close: 591.70001
#   - **Daily Change:** \(((591.70001 - 576.40002) / 576.40002) \times 100 \approx 2.65\%\)
# - **5-day Start:** (From November 4)
#   - November 4 Close: 560.67999
#   - November 7 Close: 591.70001
#   - **5-day Change:** \(((591.70001 - 560.67999) / 560.67999) \times 100 \approx 5.53\%\)
#
# ### MSFT (Microsoft Corporation)
# - **November 7, 2024:**
#   - Open: 421.12000, Close: 425.51001
#   - **Daily Change:** \(((425.51001 - 421.12000) / 421.12000) \times 100 \approx 1.04\%\)
# - **5-day Start:** (From November 4)
#   - November 4 Close: 408.45999
#   - November 7 Close: 425.51001
#   - **5-day Change:** \(((425.51001 - 408.45999) / 408.45999) \times 100 \approx 4.18\%\)
#
# ### NVDA (NVIDIA Corporation)
# - **November 7, 2024:**
#   - Open: 146.40199, Close: 148.89000
#   - **Daily Change:** \(((148.89000 - 146.40199) / 146.40199) \times 100 \approx 1.70\%\)
# - **5-day Start:** (From November 4)
#   - November 4 Close: 136.05000
#   - November 7 Close: 148.89000
#   - **5-day Change:** \(((148.89000 - 136.05000) / 136.05000) \times 100 \approx 9.43\%\)
#
# ### TSLA (Tesla, Inc.)
# - **November 7, 2024:**
#   - Open: 288.57999, Close: 296.75000
#   - **Daily Change:** \(((296.75000 - 288.57999) / 288.57999) \times 100 \approx 2.83\%\)
# - **5-day Start:** (From November 4)
#   - November 4 Close: 242.84000
#   - November 7 Close: 296.75000
#   - **5-day Change:** \(((296.75000 - 242.84000) / 242.84000) \times 100 \approx 22.20\%\)
#
# This summary includes calculations for the daily percentage change from opening to closing prices for November 7th, and the percentage change from the latest available 5-day period using closing values. Note that the 5-day review was based on the limited data provided.
